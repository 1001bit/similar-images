# %%
import torch
import clip
from PIL import Image
import os
from tqdm import tqdm

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model, preprocess = clip.load("ViT-B/32", device=device)

# %%
@torch.no_grad()
def image_to_vec(image_path: str) -> torch.Tensor:
    img = preprocess(Image.open(image_path).convert("RGB")).unsqueeze(0).to(device)
    feat = model.encode_image(img)              # shape: [1, d]
    feat = feat / feat.norm(dim=-1, keepdim=True)  # normalize for cosine similarity
    return feat.squeeze(0).cpu()

# %%
dataset_path = "dataset"
img_paths = [os.path.join(dataset_path, f) for f in os.listdir(dataset_path)]
print(img_paths)
len(img_paths)
# Out:
# ['dataset/9516.png', 'dataset/5663.png', 'dataset/5838.png', 'dataset/1609.png', 'dataset/9009.png', 'dataset/4187.png', 'dataset/1548.png', 'dataset/6197.png', 'dataset/9437.png', 'dataset/2280.png', 'dataset/8728.png', 'dataset/2711.png', 'dataset/2952.png', 'dataset/1690.png', 'dataset/2841.png', 'dataset/5084.png', 'dataset/3898.png', 'dataset/7059.png', 'dataset/7835.png', 'dataset/6506.png', 'dataset/1353.png', 'dataset/4381.png', 'dataset/0003.png', 'dataset/3615.png', 'dataset/7143.png', 'dataset/5804.png', 'dataset/2269.png', 'dataset/4582.png', 'dataset/5364.png', 'dataset/3280.png', 'dataset/4924.png', 'dataset/2385.png', 'dataset/4376.png', 'dataset/2500.png', 'dataset/0273.png', 'dataset/1648.png', 'dataset/8160.png', 'dataset/8506.png', 'dataset/8878.png', 'dataset/1067.png', 'dataset/8841.png', 'dataset/5196.png', 'dataset/6694.png', 'dataset/1730.png', 'dataset/5844.png', 'dataset/7833.png', 'dataset/5417.png', 'dataset/7999.png', 'dataset/8393.png', 'dataset/0484.png', 'dataset/5924.png', 'dataset/2420.png', 'dataset/4960.png', 'dataset/7716.png', 'dataset/8740.png', 'dataset/4275.png', 'dataset/1446.png', 'dataset/2282.png', 'dataset/2522.png', 'dataset/1032.png', 'dataset/8847.png', 'dataset/4830.png', 'dataset/6740.png', 'dataset/1042.png', 'dataset/7877.png', 'dataset/3957.png', 'dataset/0593.png', 'dataset/7967.png', 'dataset/4293.png', 'dataset/9053.png', 'dataset/7902.png', 'dataset/6914.png', 'dataset/8541.png', 'dataset/2163.png', 'dataset/6195.png', 'dataset/5398.png', 'dataset/3811.png', 'dataset/6188.png', 'dataset/3217.png', 'dataset/3566.png', 'dataset/7484.png', 'dataset/0089.png', 'dataset/8075.png', 'dataset/8489.png', 'dataset/4105.png', 'dataset/8784.png', 'dataset/0778.png', 'dataset/2031.png', 'dataset/2537.png', 'dataset/1293.png', 'dataset/1151.png', 'dataset/0855.png', 'dataset/7626.png', 'dataset/5916.png', 'dataset/6625.png', 'dataset/6895.png', 'dataset/4464.png', 'dataset/0400.png', 'dataset/1955.png', 'dataset/3530.png', 'dataset/1251.png', 'dataset/7099.png', 'dataset/1912.png', 'dataset/0012.png', 'dataset/2332.png', 'dataset/2393.png', 'dataset/7378.png', 'dataset/4469.png', 'dataset/7980.png', 'dataset/8183.png', 'dataset/1621.png', 'dataset/3857.png', 'dataset/7257.png', 'dataset/8837.png', 'dataset/7511.png', 'dataset/7232.png', 'dataset/7190.png', 'dataset/5764.png', 'dataset/7310.png', 'dataset/1207.png', 'dataset/0877.png', 'dataset/6941.png', 'dataset/3129.png', 'dataset/0943.png', 'dataset/8327.png', 'dataset/9063.png', 'dataset/1328.png', 'dataset/9547.png', 'dataset/4395.png', 'dataset/0209.png', 'dataset/2858.png', 'dataset/8889.png', 'dataset/1967.png', 'dataset/6249.png', 'dataset/7656.png', 'dataset/5377.png', 'dataset/4788.png', 'dataset/1107.png', 'dataset/7909.png', 'dataset/4938.png', 'dataset/8037.png', 'dataset/1155.png', 'dataset/2379.png', 'dataset/5055.png', 'dataset/7046.png', 'dataset/3542.png', 'dataset/9599.png', 'dataset/3511.png', 'dataset/0651.png', 'dataset/6612.png', 'dataset/4580.png', 'dataset/3156.png', 'dataset/2833.png', 'dataset/3739.png', 'dataset/2033.png', 'dataset/6631.png', 'dataset/3949.png', 'dataset/5602.png', 'dataset/7984.png', 'dataset/0044.png', 'dataset/6945.png', 'dataset/0764.png', 'dataset/6203.png', 'dataset/0837.png', 'dataset/7228.png', 'dataset/0307.png', 'dataset/2846.png', 'dataset/0806.png', 'dataset/5814.png', 'dataset/7586.png', 'dataset/9454.png', 'dataset/0282.png', 'dataset/6829.png', 'dataset/7619.png', 'dataset/6772.png', 'dataset/6070.png', 'dataset/8030.png', 'dataset/8308.png', 'dataset/4495.png', 'dataset/0447.png', 'dataset/2450.png', 'dataset/1005.png', 'dataset/0723.png', 'dataset/6382.png', 'dataset/0680.png', 'dataset/7577.png', 'dataset/8038.png', 'dataset/7213.png', 'dataset/1572.png', 'dataset/6267.png', 'dataset/6873.png', 'dataset/7249.png', 'dataset/6342.png', 'dataset/3537.png', 'dataset/2845.png', 'dataset/4832.png', 'dataset/4882.png', 'dataset/2638.png', 'dataset/0683.png', 'dataset/9559.png', ...
# 9605

# %%
vecs = torch.stack([image_to_vec(p) for p in tqdm(img_paths, desc="Embedding images")])
# Out:
# Embedding images:   0%|          | 23/9605 [00:08<56:35,  2.82it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 vecs = torch.stack([image_to_vec(p) for p in tqdm(img_paths, desc="Embedding images")])
#
# File ~/ML/4866/.venv/lib64/python3.14/site-packages/torch/utils/_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# Cell In[15], line 4, in image_to_vec(image_path)
#       1 @torch.no_grad()
#       2 def image_to_vec(image_path: str) -> torch.Tensor:
#       3     img = preprocess(Image.open(image_path).convert("RGB")).unsqueeze(0).to(device)
# ----> 4     feat = model.encode_image(img)              # shape: [1, d]
#       5     feat = feat / feat.norm(dim=-1, keepdim=True)  # normalize for cosine similarity
#       6     return feat.squeeze(0).cpu()
#
# File ~/ML/4866/.venv/lib64/python3.14/site-packages/clip/model.py:341, in CLIP.encode_image(self, image)
#     340 def encode_image(self, image):
# --> 341     return self.visual(image.type(self.dtype))
#
# File ~/ML/4866/.venv/lib64/python3.14/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/ML/4866/.venv/lib64/python3.14/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/ML/4866/.venv/lib64/python3.14/site-packages/clip/model.py:232, in VisionTransformer.forward(self, x)
#     229 x = self.ln_pre(x)
#     231 x = x.permute(1, 0, 2)  # NLD -> LND
# --> 232 x = self.transformer(x)
#     233 x = x.permute(1, 0, 2)  # LND -> NLD
#     235 x = self.ln_post(x[:, 0, :])
#
# File ~/ML/4866/.venv/lib64/python3.14/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/ML/4866/.venv/lib64/python3.14/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/ML/4866/.venv/lib64/python3.14/site-packages/clip/model.py:203, in Transformer.forward(self, x)
#     202 def forward(self, x: torch.Tensor):
# --> 203     return self.resblocks(x)
#
# File ~/ML/4866/.venv/lib64/python3.14/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/ML/4866/.venv/lib64/python3.14/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/ML/4866/.venv/lib64/python3.14/site-packages/torch/nn/modules/container.py:253, in Sequential.forward(self, input)
#     249 """
#     250 Runs the forward pass.
#     251 """
#     252 for module in self:
# --> 253     input = module(input)
#     254 return input
#
# File ~/ML/4866/.venv/lib64/python3.14/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/ML/4866/.venv/lib64/python3.14/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/ML/4866/.venv/lib64/python3.14/site-packages/clip/model.py:191, in ResidualAttentionBlock.forward(self, x)
#     189 def forward(self, x: torch.Tensor):
#     190     x = x + self.attention(self.ln_1(x))
# --> 191     x = x + self.mlp(self.ln_2(x))
#     192     return x
#
# File ~/ML/4866/.venv/lib64/python3.14/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/ML/4866/.venv/lib64/python3.14/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/ML/4866/.venv/lib64/python3.14/site-packages/torch/nn/modules/container.py:253, in Sequential.forward(self, input)
#     249 """
#     250 Runs the forward pass.
#     251 """
#     252 for module in self:
# --> 253     input = module(input)
#     254 return input
#
# File ~/ML/4866/.venv/lib64/python3.14/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/ML/4866/.venv/lib64/python3.14/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/ML/4866/.venv/lib64/python3.14/site-packages/torch/nn/modules/linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
